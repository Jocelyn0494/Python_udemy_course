# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Plotly and Cufflinks

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).
#
# ## Installation
#
# In order for this all to work, you'll need to install plotly and cufflinks to call plots directly off of a pandas dataframe. These libraries are not currently available through **conda** but are available through **pip**. Install the libraries at your command line/terminal using:
#
#     pip install plotly
#     pip install cufflinks
#
# ** NOTE: Make sure you only have one installation of Python on your computer when you do this, otherwise the installation may not work. **
#
# ## Imports and Set-up

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 3.10.0

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
#this is going to connect the javascript to your notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline() #will allow culfflinks offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Fake Data

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  1.358268  0.162124  0.210975  0.064322
# 1  0.419717  1.001015  1.375703 -0.069646
# 2 -0.310642 -2.480024  0.271604  0.816904
# 3  0.106741 -0.961611  0.009693  1.254999
# 4 -0.858574  0.664080 -0.267111  1.595550

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %% [markdown]
# ## Scatter

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10) # without mode= markers, all the points will be connected 
#size to control the size of the point
# Out:
# <div>
#
#
#             <div id="90a7fb0d-d305-40cc-a45b-aa296b36be4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("90a7fb0d-d305-40cc-a45b-aa296b36be4b")) {
#                     Plotly.newPlot(
#                         '90a7fb0d-d305-40cc-a45b-aa296b36be4b',
# ...

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="86fa47b7-2167-41ef-b787-599195a07085" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("86fa47b7-2167-41ef-b787-599195a07085")) {
#                     Plotly.newPlot(
#                         '86fa47b7-2167-41ef-b787-599195a07085',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "uid": "769401f9-7e0c-4f9f-b6a7-90f16ea8f700", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="77fb40ff-2bfd-4842-8b3c-f2b79b2845e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("77fb40ff-2bfd-4842-8b3c-f2b79b2845e9")) {
#                     Plotly.newPlot(
#                         '77fb40ff-2bfd-4842-8b3c-f2b79b2845e9',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "b4f81a88-992d-4a70-9d7d-14d20eea6f79", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="d2ae5333-8472-41a7-b7b9-70c267c06474" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d2ae5333-8472-41a7-b7b9-70c267c06474")) {
#                     Plotly.newPlot(
#                         'd2ae5333-8472-41a7-b7b9-70c267c06474',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "1d00c54c-8587-477a-a0c6-c5b91c1c13d2", "x": ["A", "B", "C", "D"], "y": [-15.81375907689415, -7.125927263262954, 0.8172530025064679, -1.09495296616389]}],
# ...

# %% [markdown]
# ## Boxplots

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="bfecf241-e54b-42c6-a269-a75c98c6397a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bfecf241-e54b-42c6-a269-a75c98c6397a")) {
#                     Plotly.newPlot(
#                         'bfecf241-e54b-42c6-a269-a75c98c6397a',
# ...

# %% [markdown]
# ## 3d Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="b95abaf6-da1a-402b-91b8-336acabfcf59" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b95abaf6-da1a-402b-91b8-336acabfcf59")) {
#                     Plotly.newPlot(
#                         'b95abaf6-da1a-402b-91b8-336acabfcf59',
# ...

# %% [markdown]
# ## Spread

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="301b41f2-c036-4731-83ec-d1b903027763" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("301b41f2-c036-4731-83ec-d1b903027763")) {
#                     Plotly.newPlot(
#                         '301b41f2-c036-4731-83ec-d1b903027763',
# ...

# %% [markdown]
# ## histogram

# %%
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>
#
#
#             <div id="07d9f36c-ff02-4483-8030-62ac68cba2d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("07d9f36c-ff02-4483-8030-62ac68cba2d4")) {
#                     Plotly.newPlot(
#                         '07d9f36c-ff02-4483-8030-62ac68cba2d4',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="d9010b8b-502b-49a7-97dd-882515d67af2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d9010b8b-502b-49a7-97dd-882515d67af2")) {
#                     Plotly.newPlot(
#                         'd9010b8b-502b-49a7-97dd-882515d67af2',
# ...

# %% [markdown]
# ## scatter_matrix()
#
# Similar to sns.pairplot()

# %%
df.scatter_matrix()#similar to seaborn pairplot
# Out:
# <div>
#
#
#             <div id="83ec0ae4-244d-4a7f-9c35-c7117abeb413" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("83ec0ae4-244d-4a7f-9c35-c7117abeb413")) {
#                     Plotly.newPlot(
#                         '83ec0ae4-244d-4a7f-9c35-c7117abeb413',
# ...

# %% [markdown]
# # Great Job!
